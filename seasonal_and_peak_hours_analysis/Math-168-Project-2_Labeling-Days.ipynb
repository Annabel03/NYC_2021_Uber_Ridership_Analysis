# %%
# import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
all_trips = pd.read_csv("uber_tripdata_2021_w_ids.csv", compression="gzip")

# %%
print("Number of rows in dataframe:", len(all_trips)) # should be 121,645,919
# Out:
# Number of rows in dataframe: 121645919

# %%
all_trips.head()
# Out:
#        pickup_datetime     dropoff_datetime  PULocationID  DOLocationID  \
# 0  2021-01-01 00:33:44  2021-01-01 00:49:07           230           166
# 1  2021-01-01 00:55:19  2021-01-01 01:18:21           152           167
# 2  2021-01-01 00:23:56  2021-01-01 00:38:05           233           142
# 3  2021-01-01 00:42:51  2021-01-01 00:45:50           142           143
# 4  2021-01-01 00:48:14  2021-01-01 01:08:42           143            78
#
#   pickup_borough                pickup_zone dropoff_borough  \
# 0      Manhattan  Times Sq/Theatre District       Manhattan
# 1      Manhattan             Manhattanville           Bronx
# 2      Manhattan        UN/Turtle Bay South       Manhattan
# 3      Manhattan        Lincoln Square East       Manhattan
# 4      Manhattan        Lincoln Square West           Bronx
#
#           dropoff_zone
# 0  Morningside Heights
# 1   Morrisania/Melrose
# 2  Lincoln Square East
# 3  Lincoln Square West
# 4         East Tremont

# %%
# separate pickup_datetime (and dropoff_datetime) into date, month, day of week, and hour

temp_1 = pd.DatetimeIndex(all_trips["pickup_datetime"])
all_trips["pickup_date"] = temp_1.date
all_trips["pickup_month"] = temp_1.month
all_trips["pickup_day"] = temp_1.weekday
all_trips["pickup_hour"] = temp_1.hour

# temp_2 = pd.DatetimeIndex(all_trips["dropoff_datetime"])
# all_trips["dropoff_date"] = temp_2.date
# all_trips["dropoff_month"] = temp_2.month
# all_trips["dropoff_day"] = temp_2.weekday
# all_trips["dropoff_hour"] = temp_2.hour

# %%
all_trips.head()
# Out:
#        pickup_datetime     dropoff_datetime  PULocationID  DOLocationID  \
# 0  2021-01-01 00:33:44  2021-01-01 00:49:07           230           166
# 1  2021-01-01 00:55:19  2021-01-01 01:18:21           152           167
# 2  2021-01-01 00:23:56  2021-01-01 00:38:05           233           142
# 3  2021-01-01 00:42:51  2021-01-01 00:45:50           142           143
# 4  2021-01-01 00:48:14  2021-01-01 01:08:42           143            78
#
#   pickup_borough                pickup_zone dropoff_borough  \
# 0      Manhattan  Times Sq/Theatre District       Manhattan
# 1      Manhattan             Manhattanville           Bronx
# 2      Manhattan        UN/Turtle Bay South       Manhattan
# 3      Manhattan        Lincoln Square East       Manhattan
# 4      Manhattan        Lincoln Square West           Bronx
#
#           dropoff_zone pickup_date  pickup_month  pickup_day  pickup_hour
# 0  Morningside Heights  2021-01-01             1           4            0
# 1   Morrisania/Melrose  2021-01-01             1           4            0
# 2  Lincoln Square East  2021-01-01             1           4            0
# 3  Lincoln Square West  2021-01-01             1           4            0
# 4         East Tremont  2021-01-01             1           4            0

# %%
# drop pickup_datetime and dropoff_datetime since we already have other time indicators
all_trips.drop(columns=["pickup_datetime", "dropoff_datetime"], inplace=True)

# %%
all_trips.head()
# Out:
#    PULocationID  DOLocationID pickup_borough                pickup_zone  \
# 0           230           166      Manhattan  Times Sq/Theatre District
# 1           152           167      Manhattan             Manhattanville
# 2           233           142      Manhattan        UN/Turtle Bay South
# 3           142           143      Manhattan        Lincoln Square East
# 4           143            78      Manhattan        Lincoln Square West
#
#   dropoff_borough         dropoff_zone pickup_date  pickup_month  pickup_day  \
# 0       Manhattan  Morningside Heights  2021-01-01             1           4
# 1           Bronx   Morrisania/Melrose  2021-01-01             1           4
# 2       Manhattan  Lincoln Square East  2021-01-01             1           4
# 3       Manhattan  Lincoln Square West  2021-01-01             1           4
# 4           Bronx         East Tremont  2021-01-01             1           4
#
#    pickup_hour
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
all_trips.dtypes

# %%
all_trips["pickup_date"] = all_trips["pickup_date"].astype("string")

# %%
all_trips.head()
# Out:
#    PULocationID  DOLocationID pickup_borough                pickup_zone  \
# 0           230           166      Manhattan  Times Sq/Theatre District
# 1           152           167      Manhattan             Manhattanville
# 2           233           142      Manhattan        UN/Turtle Bay South
# 3           142           143      Manhattan        Lincoln Square East
# 4           143            78      Manhattan        Lincoln Square West
#
#   dropoff_borough         dropoff_zone pickup_date  pickup_month  pickup_day  \
# 0       Manhattan  Morningside Heights  2021-01-01             1           4
# 1           Bronx   Morrisania/Melrose  2021-01-01             1           4
# 2       Manhattan  Lincoln Square East  2021-01-01             1           4
# 3       Manhattan  Lincoln Square West  2021-01-01             1           4
# 4           Bronx         East Tremont  2021-01-01             1           4
#
#    pickup_hour
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
all_trips.dtypes

# %%
# label day as weekday (Mon, Tue, Wed, Thu, Fri) or weekend (Sat, Sun)
# referred to https://stackoverflow.com/a/57410089
all_trips.loc[all_trips["pickup_day"].isin([0,1,2,3,4]), "PU_type_of_day"] = "weekday"
all_trips.loc[all_trips["pickup_day"].isin([5,6]), "PU_type_of_day"] = "weekend"
# all_trips.loc[all_trips["dropoff_day"].isin([0,1,2,3,4]), "DO_type_of_day"] = "weekday"
# all_trips.loc[all_trips["dropoff_day"].isin([5,6]), "DO_type_of_day"] = "weekend"

# %%
all_trips.head()
# Out:
#    PULocationID  DOLocationID pickup_borough                pickup_zone  \
# 0           230           166      Manhattan  Times Sq/Theatre District
# 1           152           167      Manhattan             Manhattanville
# 2           233           142      Manhattan        UN/Turtle Bay South
# 3           142           143      Manhattan        Lincoln Square East
# 4           143            78      Manhattan        Lincoln Square West
#
#   dropoff_borough         dropoff_zone pickup_date  pickup_month  pickup_day  \
# 0       Manhattan  Morningside Heights  2021-01-01             1           4
# 1           Bronx   Morrisania/Melrose  2021-01-01             1           4
# 2       Manhattan  Lincoln Square East  2021-01-01             1           4
# 3       Manhattan  Lincoln Square West  2021-01-01             1           4
# 4           Bronx         East Tremont  2021-01-01             1           4
#
#    pickup_hour PU_type_of_day
# 0            0        weekday
# 1            0        weekday
# 2            0        weekday
# 3            0        weekday
# 4            0        weekday

# %%
# drop pickup_day (and dropoff_day) columns since we only want to compare weekday vs weekend
all_trips.drop(columns=["pickup_day"], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[17], line 2
#       1 # drop pickup_day (and dropoff_day) columns since we only want to compare weekday vs weekend
# ----> 2 all_trips.drop(columns=["pickup_day"], inplace=True)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\generic.py:4350, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4347     new_axis = axis.take(indexer)
#    4349 bm_axis = self.ndim - axis_num - 1
# -> 4350 new_mgr = self._mgr.reindex_indexer(
#    4351     new_axis,
#    4352     indexer,
#    4353     axis=bm_axis,
#    4354     allow_dups=True,
#    4355     consolidate=consolidate,
#    4356     only_slice=only_slice,
#    4357 )
#    4358 result = self._constructor(new_mgr)
#    4359 if self.ndim == 1:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\managers.py:685, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice, use_na_proxy)
#     682     raise IndexError("Requested axis not found in manager")
#     684 if axis == 0:
# --> 685     new_blocks = self._slice_take_blocks_ax0(
#     686         indexer,
#     687         fill_value=fill_value,
#     688         only_slice=only_slice,
#     689         use_na_proxy=use_na_proxy,
#     690     )
#     691 else:
#     692     new_blocks = [
#     693         blk.take_nd(
#     694             indexer,
#    (...)
#     700         for blk in self.blocks
#     701     ]
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\managers.py:844, in BaseBlockManager._slice_take_blocks_ax0(self, slice_or_indexer, fill_value, only_slice, use_na_proxy)
#     842                     blocks.append(nb)
#     843             else:
# --> 844                 nb = blk.take_nd(taker, axis=0, new_mgr_locs=mgr_locs)
#     845                 blocks.append(nb)
#     847 return blocks
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\blocks.py:1137, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1134 else:
#    1135     allow_fill = True
# -> 1137 new_values = algos.take_nd(
#    1138     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1139 )
#    1141 # Called from three places in managers, all of which satisfy
#    1142 #  this assertion
#    1143 assert not (axis == 0 and new_mgr_locs is None)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\array_algos\take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\array_algos\take.py:158, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     156     out = np.empty(out_shape, dtype=dtype, order="F")
#     157 else:
# --> 158     out = np.empty(out_shape, dtype=dtype)
#     160 func = _get_take_nd_function(
#     161     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     162 )
#     163 func(arr, indexer, out, fill_value)
#
# MemoryError: Unable to allocate 4.53 GiB for an array with shape (5, 121645919) and data type object

# %%
all_trips.head()
# Out:
#    PULocationID  DOLocationID pickup_borough                pickup_zone  \
# 0           230           166      Manhattan  Times Sq/Theatre District
# 1           152           167      Manhattan             Manhattanville
# 2           233           142      Manhattan        UN/Turtle Bay South
# 3           142           143      Manhattan        Lincoln Square East
# 4           143            78      Manhattan        Lincoln Square West
#
#   dropoff_borough         dropoff_zone pickup_date  pickup_month  pickup_day  \
# 0       Manhattan  Morningside Heights  2021-01-01             1           4
# 1           Bronx   Morrisania/Melrose  2021-01-01             1           4
# 2       Manhattan  Lincoln Square East  2021-01-01             1           4
# 3       Manhattan  Lincoln Square West  2021-01-01             1           4
# 4           Bronx         East Tremont  2021-01-01             1           4
#
#    pickup_hour PU_type_of_day
# 0            0        weekday
# 1            0        weekday
# 2            0        weekday
# 3            0        weekday
# 4            0        weekday

# %%
compression_opts = dict(method="gzip")
all_trips.to_csv("./uber_tripdata_2021_labeled_days_with_dates.csv", index=False, compression=compression_opts)
